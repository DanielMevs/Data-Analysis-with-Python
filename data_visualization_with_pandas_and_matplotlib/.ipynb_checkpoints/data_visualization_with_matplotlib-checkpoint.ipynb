# %% [markdown]
# # 1. BASIC SINGLE LINE PLOT

# %%
# The plot method on Pandas Series and DataFrames is just a simple wrapper around plt.plot():
import matplotlib.pyplot as plt
import pandas as pd
from datetime import datetime

# %%
# Use Pandas read_csv to read crypto daily prices (BTC, ETH, and LTC)
investment_df = pd.read_csv('crypto_daily_prices.csv')
investment_df
# Out:
#            Date  BTC-USD Price  ETH-USD Price  LTC-USD Price
# 0     9/17/2014     457.334015            NaN       5.058550
# 1     9/18/2014     424.440002            NaN       4.685230
# 2     9/19/2014     394.795990            NaN       4.327770
# 3     9/20/2014     408.903992            NaN       4.286440
# 4     9/21/2014     398.821014            NaN       4.245920
# ...         ...            ...            ...            ...
# 2380  3/28/2021   55950.746090    1691.355957     185.028488
# 2381  3/29/2021   57750.199220    1819.684937     194.474777
# 2382  3/30/2021   58917.691410    1846.033691     196.682098
# 2383  3/31/2021   58918.832030    1918.362061     197.499100
# 2384   4/1/2021   59095.808590    1977.276855     204.112518
#
# [2385 rows x 4 columns]

# %%
# Use matplotlib on the Pandas DataFrame to plot the data
investment_df.plot(x='Date', y='BTC-USD Price', label='Bitcoin Price', linewidth=3, figsize=(14, 6))
plt.ylabel('Price [$]')
plt.xlabel('Date')
plt.title('Bitcoin Prices over Time')
plt.legend(loc='upper right')
plt.grid()

# %% [markdown]
# **MINI CHALLENGE #1:**
# - **Plot similar kind of graph for Ethereum instead**
# - **Change the line color to red**

# %%
investment_df.plot(x='Date', y='ETH-USD Price', label='ETH Price', linewidth=4, color='r', figsize=(14, 6))
plt.ylabel('Price [$]')
plt.xlabel('Date')
plt.title('Ethereum Prices over Time')
plt.legend(loc='upper right')
plt.grid()

# %% [markdown]
# # 2. DOWNLOAD DATA DIRECTLY FROM YAHOO FINANCE

# %%
# yfinance library offers an easy, reliable and Pythonic way to download market data from Yahoo finance
# !pip install yfinance
import yfinance as yf
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.36-py2.py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.4/72.4 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pandas>=1.3.0 in /Users/danielmevs/anaconda3/lib/python3.11/site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in /Users/danielmevs/anaconda3/lib/python3.11/site-packages (from yfinance) (1.24.3)
# Collecting requests>=2.31 (from yfinance)
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Using cached multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: lxml>=4.9.1 in /Users/danielmevs/anaconda3/lib/python3.11/site-packages (from yfinance) (4.9.2)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/danielmevs/anaconda3/lib/python3.11/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /Users/danielmevs/anaconda3/lib/python3.11/site-packages (from yfinance) (2022.7)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.0.tar.gz (314 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.6/314.6 kB 6.0 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.0.tar.gz (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 34.4 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/danielmevs/anaconda3/lib/python3.11/site-packages (from yfinance) (4.12.2)
# Collecting html5lib>=1.1 (from yfinance)
#   Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Requirement already satisfied: soupsieve>1.2 in /Users/danielmevs/anaconda3/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4)
# Requirement already satisfied: six>=1.9 in /Users/danielmevs/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Users/danielmevs/anaconda3/lib/python3.11/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/danielmevs/anaconda3/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/danielmevs/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/danielmevs/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/danielmevs/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/danielmevs/anaconda3/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2023.5.7)
# Building wheels for collected packages: frozendict, peewee
#   Building wheel for frozendict (pyproject.toml) ... done
#   Created wheel for frozendict: filename=frozendict-2.4.0-py3-none-any.whl size=15425 sha256=696b41a72ea24f7068baa164c78cf6291257b10978ac9ac652ecc0769cc18f47
#   Stored in directory: /Users/danielmevs/Library/Caches/pip/wheels/31/dd/81/a814e6f8cde8a1bbc1f088fdc273943371f10478b91a605e14
#   Building wheel for peewee (pyproject.toml) ... done
#   Created wheel for peewee: filename=peewee-3.17.0-cp311-cp311-macosx_11_0_arm64.whl size=244831 sha256=3aa34dc1205f3d0d3452e16c949d03e53a89e0927757505a33152cda751d09cf
#   Stored in directory: /Users/danielmevs/Library/Caches/pip/wheels/02/20/23/74a10d0cd31f5d41c19b92ddf4c138ceff01b9f4675f19dbf5
# Successfully built frozendict peewee
# Installing collected packages: peewee, multitasking, requests, html5lib, frozendict, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.29.0
#     Uninstalling requests-2.29.0:
#       Successfully uninstalled requests-2.29.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.41 requires requests_mock, which is not installed.
# spyder 5.4.3 requires pyqt5<5.16, which is not installed.
# spyder 5.4.3 requires pyqtwebengine<5.16, which is not installed.
# conda-repo-cli 1.0.41 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.41 requires nbformat==5.4.0, but you have nbformat 5.7.0 which is incompatible.
# conda-repo-cli 1.0.41 requires requests==2.28.1, but you have requests 2.31.0 which is incompatible.
# Successfully installed frozendict-2.4.0 html5lib-1.1 multitasking-0.0.11 peewee-3.17.0 requests-2.31.0 yfinance-0.2.36
# /Users/danielmevs/anaconda3/lib/python3.11/site-packages/yfinance/base.py:48: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   _empty_series = pd.Series()

# %%
# List all Ticker Symbols in the list below, let's start with one!
investments_list = ['BTC-USD']

# Specify the start and end dates
start = datetime(2010, 1, 1)
end = datetime(2021, 5, 16)

# Download the data from Yahoo Finance, make sure to reset index!
df = yf.download(investments_list, start=start, end=end)
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2021-05-11  55847.242188  56872.542969  54608.652344  56704.574219
# 2021-05-12  56714.531250  57939.363281  49150.535156  49150.535156
# 2021-05-13  49735.433594  51330.843750  46980.019531  49716.191406
# 2021-05-14  49682.980469  51438.117188  48868.578125  49880.535156
# 2021-05-15  49855.496094  50639.664062  46664.140625  46760.187500
#
#                Adj Close       Volume
# Date
# 2014-09-17    457.334015     21056800
# 2014-09-18    424.440002     34483200
# 2014-09-19    394.795990     37919700
# 2014-09-20    408.903992     36863600
# 2014-09-21    398.821014     26580100
# ...                  ...          ...
# 2021-05-11  56704.574219  61308396325
# 2021-05-12  49150.535156  75215403907
# 2021-05-13  49716.191406  96721152926
# 2021-05-14  49880.535156  55737497453
# 2021-05-15  46760.187500  59161047474
#
# [2433 rows x 6 columns]

# %%
# Reset index as follows:
df.reset_index(inplace=True)
df
# Out:
#            Date          Open          High           Low         Close  \
# 0    2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1    2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2    2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3    2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4    2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...         ...           ...           ...           ...           ...
# 2428 2021-05-11  55847.242188  56872.542969  54608.652344  56704.574219
# 2429 2021-05-12  56714.531250  57939.363281  49150.535156  49150.535156
# 2430 2021-05-13  49735.433594  51330.843750  46980.019531  49716.191406
# 2431 2021-05-14  49682.980469  51438.117188  48868.578125  49880.535156
# 2432 2021-05-15  49855.496094  50639.664062  46664.140625  46760.187500
#
#          Adj Close       Volume
# 0       457.334015     21056800
# 1       424.440002     34483200
# 2       394.795990     37919700
# 3       408.903992     36863600
# 4       398.821014     26580100
# ...            ...          ...
# 2428  56704.574219  61308396325
# 2429  49150.535156  75215403907
# 2430  49716.191406  96721152926
# 2431  49880.535156  55737497453
# 2432  46760.187500  59161047474
#
# [2433 rows x 7 columns]

# %% [markdown]
# **MINI CHALLENGE #2:**
# - **Use Yahoo Finance to download Ethereum data instead of BTC**
# - **USe Yahoo Finance to download BTC, ETH, and LTC**

# %%
# List all Ticker Symbols in the list below, let's start with one!
investments_list = ['ETH-USD']

# Specify the start and end dates
start = datetime(2010, 1, 1)
end = datetime(2021, 5, 16)

# Download the data from Yahoo Finance, make sure to reset index!
df = yf.download(investments_list, start=start, end=end)
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2017-11-09   308.644989   329.451996   307.056000   320.884003   320.884003
# 2017-11-10   320.670990   324.717987   294.541992   299.252991   299.252991
# 2017-11-11   298.585999   319.453003   298.191986   314.681000   314.681000
# 2017-11-12   314.690002   319.153015   298.513000   307.907990   307.907990
# 2017-11-13   307.024994   328.415009   307.024994   316.716003   316.716003
# ...                 ...          ...          ...          ...          ...
# 2021-05-11  3948.271973  4178.208984  3783.889404  4168.701172  4168.701172
# 2021-05-12  4174.635742  4362.350586  3785.848633  3785.848633  3785.848633
# 2021-05-13  3828.918457  4032.563477  3549.407227  3715.148438  3715.148438
# 2021-05-14  3720.122314  4171.017090  3703.399902  4079.057373  4079.057373
# 2021-05-15  4075.951660  4129.185547  3638.122070  3638.122070  3638.122070
#
#                  Volume
# Date
# 2017-11-09    893249984
# 2017-11-10    885985984
# 2017-11-11    842300992
# 2017-11-12   1613479936
# 2017-11-13   1041889984
# ...                 ...
# 2021-05-11  52679737865
# 2021-05-12  69023382175
# 2021-05-13  78398214539
# 2021-05-14  48174271215
# 2021-05-15  42422321751
#
# [1284 rows x 6 columns]

# %%
# List all Ticker Symbols in the list below, let's start with one!
investments_list = ['BTC-USD', 'ETH-USD', 'LTC-USD']

# Specify the start and end dates
start = datetime(2010, 1, 1)
end = datetime(2021, 5, 16)

# Download the data from Yahoo Finance, make sure to reset index!
df = yf.download(investments_list, start=start, end=end)
df
# Out:
# [*********************100%%**********************]  3 of 3 completed
# Price          Adj Close                                  Close               \
# Ticker           BTC-USD      ETH-USD     LTC-USD       BTC-USD      ETH-USD
# Date
# 2014-09-17    457.334015          NaN    5.058550    457.334015          NaN
# 2014-09-18    424.440002          NaN    4.685230    424.440002          NaN
# 2014-09-19    394.795990          NaN    4.327770    394.795990          NaN
# 2014-09-20    408.903992          NaN    4.286440    408.903992          NaN
# 2014-09-21    398.821014          NaN    4.245920    398.821014          NaN
# ...                  ...          ...         ...           ...          ...
# 2021-05-11  56704.574219  4168.701172  377.388794  56704.574219  4168.701172
# 2021-05-12  49150.535156  3785.848633  303.084869  49150.535156  3785.848633
# 2021-05-13  49716.191406  3715.148438  316.909332  49716.191406  3715.148438
# 2021-05-14  49880.535156  4079.057373  326.233856  49880.535156  4079.057373
# 2021-05-15  46760.187500  3638.122070  299.772522  46760.187500  3638.122070
#
# Price                           High                                    Low  \
# Ticker         LTC-USD       BTC-USD      ETH-USD     LTC-USD       BTC-USD
# Date
# 2014-09-17    5.058550    468.174011          NaN    5.170770    452.421997
# 2014-09-18    4.685230    456.859985          NaN    5.065430    413.104004
# 2014-09-19    4.327770    427.834991          NaN    4.755820    384.532013
# 2014-09-20    4.286440    423.295990          NaN    4.616080    389.882996
# 2014-09-21    4.245920    412.425995          NaN    4.300130    393.181000
# ...                ...           ...          ...         ...           ...
# 2021-05-11  377.388794  56872.542969  4178.208984  378.859131  54608.652344
# 2021-05-12  303.084869  57939.363281  4362.350586  393.132477  49150.535156
# 2021-05-13  316.909332  51330.843750  4032.563477  332.028473  46980.019531
# 2021-05-14  326.233856  51438.117188  4171.017090  338.098053  48868.578125
# 2021-05-15  299.772522  50639.664062  4129.185547  331.592621  46664.140625
#
# Price                                        Open                           \
# Ticker          ETH-USD     LTC-USD       BTC-USD      ETH-USD     LTC-USD
# Date
# 2014-09-17          NaN    4.965950    465.864014          NaN    5.085890
# 2014-09-18          NaN    4.579960    456.859985          NaN    5.065430
# 2014-09-19          NaN    4.254350    424.102997          NaN    4.687290
# 2014-09-20          NaN    4.202190    394.673004          NaN    4.329200
# 2014-09-21          NaN    4.154990    408.084991          NaN    4.263070
# ...                 ...         ...           ...          ...         ...
# 2021-05-11  3783.889404  345.298828  55847.242188  3948.271973  359.258087
# 2021-05-12  3785.848633  303.084869  56714.531250  4174.635742  377.670532
# 2021-05-13  3549.407227  292.280670  49735.433594  3828.918457  310.102386
# 2021-05-14  3703.399902  308.707672  49682.980469  3720.122314  317.517212
# 2021-05-15  3638.122070  297.590851  49855.496094  4075.951660  326.397919
#
# Price            Volume
# Ticker          BTC-USD       ETH-USD     LTC-USD
# Date
# 2014-09-17     21056800           NaN     3071840
# 2014-09-18     34483200           NaN     4569260
# 2014-09-19     37919700           NaN     3917450
# 2014-09-20     36863600           NaN     5490660
# 2014-09-21     26580100           NaN     2931220
# ...                 ...           ...         ...
# 2021-05-11  61308396325  5.267974e+10  8798204078
# 2021-05-12  75215403907  6.902338e+10  8782996412
# 2021-05-13  96721152926  7.839821e+10  9777636796
# 2021-05-14  55737497453  4.817427e+10  6413801038
# 2021-05-15  59161047474  4.242232e+10  5642887118
#
# [2433 rows x 18 columns]

# %% [markdown]
# # 3. MULTIPLE PLOTS

# %%
# Use Pandas read_csv to read crypto daily prices (BTC, ETH, and LTC)
# Out:
#            Date  BTC-USD Price  ETH-USD Price  LTC-USD Price
# 0     9/17/2014     457.334015            NaN       5.058550
# 1     9/18/2014     424.440002            NaN       4.685230
# 2     9/19/2014     394.795990            NaN       4.327770
# 3     9/20/2014     408.903992            NaN       4.286440
# 4     9/21/2014     398.821014            NaN       4.245920
# ...         ...            ...            ...            ...
# 2380  3/28/2021   55950.746090    1691.355957     185.028488
# 2381  3/29/2021   57750.199220    1819.684937     194.474777
# 2382  3/30/2021   58917.691410    1846.033691     196.682098
# 2383  3/31/2021   58918.832030    1918.362061     197.499100
# 2384   4/1/2021   59095.808590    1977.276855     204.112518
#
# [2385 rows x 4 columns]

# %% [markdown]
# **MINI CHALLENGE #3:**
# - **Add Litecoin (LTC) to the list and plot similar kind of graph showing all three crypto currencies**

# %% [markdown]
# # 4. SUBPLOTS

# %% [markdown]
# **MINI CHALLENGE #4:**
# - **Try to set subplots = False and examine the output.**

# %% [markdown]
# # 5. SCATTERPLOT

# %%
# Read daily return data using pandas
# Out:
#            Date       BTC       ETH       LTC
# 0     9/17/2014  0.000000  0.000000  0.000000
# 1     9/18/2014 -7.192558       NaN -7.379983
# 2     9/19/2014 -6.984264       NaN -7.629499
# 3     9/20/2014  3.573492       NaN -0.955003
# 4     9/21/2014 -2.465854       NaN -0.945300
# ...         ...       ...       ...       ...
# 2380  3/28/2021 -0.040672 -1.464535  0.107149
# 2381  3/29/2021  3.216138  7.587343  5.105316
# 2382  3/30/2021  2.021625  1.447984  1.135017
# 2383  3/31/2021  0.001936  3.918042  0.415392
# 2384   4/1/2021  0.300374  3.071099  3.348582
#
# [2385 rows x 4 columns]

# %%
# Plot Daily returns of BTC vs. ETH

# %% [markdown]
# **MINI CHALLENGE #5:**
# - **Plot the daily returns of BTC vs. LTC**

# %% [markdown]
# # 6. PIE CHART

# %%
# Define a dictionary with all crypto allocation in a portfolio
# Note that total summation = 100%

# %%
# Out:
#      allocation %
# BTC            20
# ETH            55
# LTC             5
# XRP            17
# ADA             3

# %%
# Use matplotlib to plot a pie chart
# Out:
# Text(0.5, 1.0, 'CRYPTO PORTFOLIO PIE CHART')

# %% [markdown]
# **MINI CHALLENGE #6:**
# - **Assume that you became bullish on XRP and decided to allocate 60% of your assets in it. You also decided to equally divide the rest of your assets in other coins (BTC, LTC, ADA, and ETH). Change the allocations and plot the pie chart.**
# - **Use 'explode' to increase the separation between XRP and the rest of the portfolio (External Research is Required)**

# %% [markdown]
# # 7. HISTOGRAMS

# %%
# A histogram represents data using bars with various heights
# Each bar groups numbers into specific ranges
# Taller bars show that more data falls within that specific range
# Out:
#            Date       BTC       ETH       LTC
# 0     9/17/2014  0.000000  0.000000  0.000000
# 1     9/18/2014 -7.192558       NaN -7.379983
# 2     9/19/2014 -6.984264       NaN -7.629499
# 3     9/20/2014  3.573492       NaN -0.955003
# 4     9/21/2014 -2.465854       NaN -0.945300
# ...         ...       ...       ...       ...
# 2380  3/28/2021 -0.040672 -1.464535  0.107149
# 2381  3/29/2021  3.216138  7.587343  5.105316
# 2382  3/30/2021  2.021625  1.447984  1.135017
# 2383  3/31/2021  0.001936  3.918042  0.415392
# 2384   4/1/2021  0.300374  3.071099  3.348582
#
# [2385 rows x 4 columns]

# %% [markdown]
# **MINI CHALLENGE #7:**
# - **Plot the histogram for ETH returns using 30 bins with red color**

# %% [markdown]
# **FINAL BREAKOUT ROOM CHALLENGE:**
# - **Use the stock_daily_prices.csv data that is included in the course/workshop package, plot a graph containing all prices of AAPL, sp500 and GOOG on one graph**
# - **Plot a subplot containing all prices of AAPL, sp500 and GOOG in individual graphs**
# - **Add legends indicating S&P500, AAPL and GOOG**
# - **Place the legend in the "upper center" location**

# %% [markdown]
# # EXCELLENT JOB!

# %% [markdown]
# # MINI CHALLENGES SOLUTIONS

# %% [markdown]
# **MINI CHALLENGE #1 SOLUTION:**
# - **Plot similar kind of graph for Ethereum instead**
# - **Change the color line to red**

# %%
investments_df.plot(x = 'Date', y = 'ETH-USD Price', label = 'ETH Price', linewidth = 3, color = 'r', figsize = (14, 6));
plt.ylabel('Price [$]')
plt.title('Ethereum Price')
plt.legend(loc = "upper right")
plt.grid()

# %% [markdown]
# **MINI CHALLENGE #2 SOLUTION:**
# - **Use Yahoo Finance to download Ethereum data instead of BTC**
# - **USe Yahoo Finance to download BTC, ETH, and LTC**

# %%
# yfinance library offers an easy, reliable and Pythonic way to download market data from Yahoo finance
# !pip install yfinance
import yfinance as yf
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.59)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.1.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.19.5)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.6.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.9)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.23.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->yfinance) (2020.12.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)

# %%
# List all Ticker Symbols in the list below 
investments_list = ["ETH-USD"]

# Specify the start and end dates
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2021, 4, 16)

# Download the data from Yahoo Finance, make sure to reset index!
df = yf.download(investments_list, start = start, end = end)
df.reset_index(inplace = True)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#            Date         Open  ...    Adj Close       Volume
# 0    2015-08-07     2.831620  ...     2.772120       164329
# 1    2015-08-08     2.793760  ...     0.753325       674188
# 2    2015-08-09     0.706136  ...     0.701897       532170
# 3    2015-08-10     0.713989  ...     0.708448       405283
# 4    2015-08-11     0.708087  ...     1.067860      1463100
# ...         ...          ...  ...          ...          ...
# 2071 2021-04-12  2157.361816  ...  2139.353271  21727936609
# 2072 2021-04-13  2139.364258  ...  2299.187744  29456642939
# 2073 2021-04-14  2299.347900  ...  2435.104980  35592822986
# 2074 2021-04-15  2436.034668  ...  2519.116211  32325606817
# 2075 2021-04-16  2516.601807  ...  2431.946533  36196928256
#
# [2076 rows x 7 columns]

# %%
# List all Ticker Symbols in the list below 
investments_list = ['BTC-USD', 'ETH-USD', 'LTC-USD']

# Specify the start and end dates
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2021, 4, 16)

# Download the data from Yahoo Finance, make sure to reset index!
df = yf.download(investments_list, start = start, end = end)
df.reset_index(inplace = True)
df
# Out:
# [*********************100%***********************]  3 of 3 completed
#            Date     Adj Close  ...        Volume
#                       BTC-USD  ...       ETH-USD      LTC-USD
# 0    2014-09-17    457.334015  ...           NaN      3071840
# 1    2014-09-18    424.440002  ...           NaN      4569260
# 2    2014-09-19    394.795990  ...           NaN      3917450
# 3    2014-09-20    408.903992  ...           NaN      5490660
# 4    2014-09-21    398.821014  ...           NaN      2931220
# ...         ...           ...  ...           ...          ...
# 2395 2021-04-12  59893.453125  ...  2.172794e+10   5220366581
# 2396 2021-04-13  63503.457031  ...  2.945664e+10   6908471654
# 2397 2021-04-14  63109.695312  ...  3.559282e+10   8215124752
# 2398 2021-04-15  63314.011719  ...  3.232561e+10   6470712244
# 2399 2021-04-16  61572.789062  ...  3.619693e+10  11850832933
#
# [2400 rows x 19 columns]

# %% [markdown]
# **MINI CHALLENGE #3 SOLUTION:**
# - **Add Litecoin (LTC) to the list and plot similar kind of graph showing all three currencies**

# %%
investments_df.plot(x = 'Date', y = [ 'BTC-USD Price', 'ETH-USD Price', 'LTC-USD Price'], linewidth = 2, figsize = (14,6))
plt.ylabel('Price')
plt.title('Crypto Prices')
plt.grid()

# %% [markdown]
# **MINI CHALLENGE #4 SOLUTION:**
# - **Try to set subplots = False and examine the output.**
# - **Try to set sharey to True and examine the output. What do you infer?**

# %%
investments_df.plot(x = 'Date', title = 'Crypto Prices', subplots = False, grid = True, figsize = (14, 6));

# %% [markdown]
# **MINI CHALLENGE #5 SOLUTION:**
# - **Plot the daily returns of BTC vs. LTC**

# %%
# Plot Daily returns of BTC vs. ETH
daily_return_df.plot.scatter('BTC', 'LTC', figsize = (12, 7))

# %% [markdown]
# **MINI CHALLENGE #6 SOLUTION:**
# - **Assume that you became bullish on XRP and decided to allocate 60% of your assets in it. You also decided to equally divide the rest of your assets in other coins (BTC, LTC, ADA, and ETH). Change the allocations and plot the pie chart.**
# - **Use 'explode' to increase the separation between BTC and the rest of the portfolio (External Research is Required)**

# %%
my_dict =  {'allocation %': [10, 10, 10, 60, 10]}
explode = (0, 0, 0, 0.2, 0)  

crypto_df = pd.DataFrame(data = my_dict, index = ['BTC', 'ETH', 'LTC', 'XRP', 'ADA'])
crypto_df.plot.pie(y = 'allocation %', explode = explode, figsize = (8, 8))

plt.title('CRYPTO PORTFOLIO PIE CHART')
# Out:
# Text(0.5, 1.0, 'CRYPTO PORTFOLIO PIE CHART')

# %% [markdown]
# **MINI CHALLENGE #7 SOLUTION:**
# - **Plot the histogram for ETH returns using 30 bins with red color**

# %%
mu = daily_return_df['ETH'].mean() # mean of distribution
sigma = daily_return_df['ETH'].std() # standard deviation of distribution
 
num_bins = 40

# Plot the histogram of the returns
plt.figure(figsize = (20, 15)) 

daily_return_df['ETH'].plot.hist(bins = 30, alpha = 0.5, facecolor = 'r', figsize = (12, 6))

plt.grid()
plt.ylabel('Probability')
plt.title('Histogram: mu=' + str(mu) + ', sigma=' +str(sigma));

# %% [markdown]
# **FINAL BREAKOUT ROOM CHALLENGE:**
# - **Import stock_daily_prices.csv data that's included in the course/workshop package**
# - **On one graph, plot the following 3 stocks only: AAPL, sp500 and GOOG**
# - **Add legends indicating S&P500, AAPL and GOOG**
# - **Place the legend in the "upper center" location**
# - **Plot subplots containing prices of AAPL, sp500 and GOOG**

# %%
stocks_df = pd.read_csv('stock_daily_prices.csv')
stocks_df
# Out:
#             Date        AAPL          BA  ...         TSLA         GOOG        sp500
# 0     2012-01-12   60.198570   75.510002  ...    28.250000   313.644379  1295.500000
# 1     2012-01-13   59.972858   74.599998  ...    22.790001   311.328064  1289.089966
# 2     2012-01-17   60.671429   75.239998  ...    26.600000   313.116364  1293.670044
# 3     2012-01-18   61.301430   75.059998  ...    26.809999   315.273285  1308.040039
# 4     2012-01-19   61.107143   75.559998  ...    26.760000   318.590851  1314.500000
# ...          ...         ...         ...  ...          ...          ...          ...
# 2154  2020-08-05  440.250000  174.279999  ...  1485.020020  1473.609985  3327.770020
# 2155  2020-08-06  455.609985  172.199997  ...  1489.579956  1500.099976  3349.159912
# 2156  2020-08-07  444.450012  170.020004  ...  1452.709961  1494.489990  3351.280029
# 2157  2020-08-10  450.910004  179.410004  ...  1418.569946  1496.099976  3360.469971
# 2158  2020-08-11  437.500000  180.130005  ...  1374.390015  1480.319946  3333.689941
#
# [2159 rows x 10 columns]

# %%
stocks_df.plot(x = 'Date', y = ['AAPL', 'sp500', 'GOOG'], linewidth = 3, figsize = (12, 8))
plt.ylabel('Price')
plt.title('Stock Prices')
plt.legend(loc = "upper center")
plt.grid()

# %%
stocks_df.plot(x = 'Date', y = ['AAPL', 'sp500', 'GOOG'], subplots = True, grid = True, linewidth = 3, figsize = (12, 8))
plt.ylabel('Price')
plt.title('Stock Prices')
plt.legend(loc = "upper center")
